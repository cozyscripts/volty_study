# %%
import pandas as pd

climate_df = pd.read_csv('climate_data.csv')
station_df = pd.read_csv('station_detail.csv')

# %%
# Checking the station_id keys in both dfs
len(station_df['station_id'].unique())
climate_df.head()
# Out:
#          date    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# 0  01-01-2010  21.4  30.2  27.1    82.0   9.0  0.5   7.0   90.0     5.0
# 1  02-01-2010  21.0  29.6  25.7    95.0  24.0  0.2   6.0   90.0     4.0
# 2  03-01-2010  20.2  26.8  24.5    98.0  63.0  0.0   5.0   90.0     4.0
# 3  04-01-2010  21.0  29.2  25.8    90.0   0.0  0.1   4.0  225.0     3.0
# 4  05-01-2010  21.2  30.0  26.7    90.0   2.0  0.4   NaN    NaN     NaN
#
#   ddd_car  station_id
# 0      E        96001
# 1      E        96001
# 2      E        96001
# 3      SW       96001
# 4     NaN       96001

# %%
# Joining Climate dataframe with station dataframe based off the unique key they share which is station_id
climate_df.join(station_df, how='left', on='station_id', lsuffix='_climate').head()
# Out:
#          date    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# 0  01-01-2010  21.4  30.2  27.1    82.0   9.0  0.5   7.0   90.0     5.0
# 1  02-01-2010  21.0  29.6  25.7    95.0  24.0  0.2   6.0   90.0     4.0
# 2  03-01-2010  20.2  26.8  24.5    98.0  63.0  0.0   5.0   90.0     4.0
# 3  04-01-2010  21.0  29.2  25.8    90.0   0.0  0.1   4.0  225.0     3.0
# 4  05-01-2010  21.2  30.0  26.7    90.0   2.0  0.4   NaN    NaN     NaN
#
#   ddd_car  station_id_climate  station_id station_name region_name  latitude  \
# 0      E                96001         NaN          NaN         NaN       NaN
# 1      E                96001         NaN          NaN         NaN       NaN
# 2      E                96001         NaN          NaN         NaN       NaN
# 3      SW               96001         NaN          NaN         NaN       NaN
# 4     NaN               96001         NaN          NaN         NaN       NaN
#
#    longitude  region_id  province_id
# ...

# %%
climate_df.head()
# Out:
#          date    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# 0  01-01-2010  21.4  30.2  27.1    82.0   9.0  0.5   7.0   90.0     5.0
# 1  02-01-2010  21.0  29.6  25.7    95.0  24.0  0.2   6.0   90.0     4.0
# 2  03-01-2010  20.2  26.8  24.5    98.0  63.0  0.0   5.0   90.0     4.0
# 3  04-01-2010  21.0  29.2  25.8    90.0   0.0  0.1   4.0  225.0     3.0
# 4  05-01-2010  21.2  30.0  26.7    90.0   2.0  0.4   NaN    NaN     NaN
#
#   ddd_car  station_id
# 0      E        96001
# 1      E        96001
# 2      E        96001
# 3      SW       96001
# 4     NaN       96001

# %%
climate_df.describe()
# Out:
#                   Tn             Tx           Tavg         RH_avg  \
# count  565882.000000  551529.000000  544160.000000  541083.000000
# mean       23.312111      31.528955      26.855475      82.489365
# std         2.280687       2.311659       1.939656      14.337669
# min         0.000000       0.000000       0.000000      24.000000
# 25%        23.000000      30.500000      26.200000      79.000000
# 50%        24.000000      31.800000      27.200000      83.000000
# 75%        25.000000      33.000000      28.000000      87.000000
# max       246.000000     334.000000     141.600000    7520.000000
#
#                   RR             ss           ff_x          ddd_x  \
# count  463881.000000  545544.000000  579051.000000  576137.000000
# mean        8.680760       5.083199       4.709601     188.488325
# std        17.928752       3.261586       2.612285     107.657452
# min        -1.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Getting Station Detail Data

# %%
station_df = pd.read_csv('station_detail.csv')
station_df.head()
# Out:
#    station_id                                       station_name  \
# 0       96001                   Stasiun Meteorologi Maimun Saleh
# 1       96003  Balai Besar Meteorologi Klimatologi  dan Geofi...
# 2       96004  Balai Besar Meteorologi Klimatologi dan Geofis...
# 3       96009                   Stasiun Meteorologi Malikussaleh
# 4       96011           Stasiun Meteorologi Sultan Iskandar Muda
#
#        region_name  latitude  longitude  region_id  province_id
# 0      Kota Sabang   5.87655   95.33785         20            1
# 1      Kab. Badung  -8.73810  115.17860        272           17
# 2    Kota Makassar  -5.14283  119.45227        412           26
# 3  Kab. Aceh Utara   5.22869   96.94749          8            1
# 4  Kab. Aceh Besar   5.52244   95.41700          6            1

# %%
len(climate_df['station_id'].unique())
# Out:
# 173

# %% [markdown]
# ## Joining two Pandas datasets together based off a key

# %%
climate_df.join(station_df, how='left', on='station_id', lsuffix='_climate').head()
# Out:
#          date    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# 0  01-01-2010  21.4  30.2  27.1    82.0   9.0  0.5   7.0   90.0     5.0
# 1  02-01-2010  21.0  29.6  25.7    95.0  24.0  0.2   6.0   90.0     4.0
# 2  03-01-2010  20.2  26.8  24.5    98.0  63.0  0.0   5.0   90.0     4.0
# 3  04-01-2010  21.0  29.2  25.8    90.0   0.0  0.1   4.0  225.0     3.0
# 4  05-01-2010  21.2  30.0  26.7    90.0   2.0  0.4   NaN    NaN     NaN
#
#   ddd_car  station_id_climate  station_id station_name region_name  latitude  \
# 0      E                96001         NaN          NaN         NaN       NaN
# 1      E                96001         NaN          NaN         NaN       NaN
# 2      E                96001         NaN          NaN         NaN       NaN
# 3      SW               96001         NaN          NaN         NaN       NaN
# 4     NaN               96001         NaN          NaN         NaN       NaN
#
#    longitude  region_id  province_id
# ...

# %%
# The Dataframe line with the station_id 96001 filtered
station_df[station_df['station_id'] == 96001]

# Return 'True' if 96001 in station_df/station_ids
# Out:
#    station_id                      station_name  region_name  latitude  \
# 0       96001  Stasiun Meteorologi Maimun Saleh  Kota Sabang   5.87655
#
#    longitude  region_id  province_id
# 0   95.33785         20            1

# %%
climate_station_df = climate_df.merge(station_df, how='left', on='station_id')

# %%
climate_station_df
# Out:
#               date    Tn    Tx  Tavg  RH_avg    RR    ss  ff_x  ddd_x  ff_avg  \
# 0       01-01-2010  21.4  30.2  27.1    82.0   9.0   0.5   7.0   90.0     5.0
# 1       02-01-2010  21.0  29.6  25.7    95.0  24.0   0.2   6.0   90.0     4.0
# 2       03-01-2010  20.2  26.8  24.5    98.0  63.0   0.0   5.0   90.0     4.0
# 3       04-01-2010  21.0  29.2  25.8    90.0   0.0   0.1   4.0  225.0     3.0
# 4       05-01-2010  21.2  30.0  26.7    90.0   2.0   0.4   NaN    NaN     NaN
# 5       06-01-2010  21.2  30.0  26.1    93.0  11.0   0.3   NaN    NaN     NaN
# 6       07-01-2010  21.4  29.0  25.4    96.0   2.0   0.1   NaN    NaN     NaN
# 7       08-01-2010  21.8  29.8  26.8    91.0   3.0   0.6   5.0   90.0     4.0
# 8       09-01-2010  21.8  30.2  26.7    92.0   3.0   0.7   4.0   90.0     3.0
# 9       10-01-2010  20.0  30.2  27.1    88.0  28.0   0.6   5.0   90.0     4.0
# 10      11-01-2010  20.0  30.2  25.7    92.0   4.0   0.6   4.0   90.0     3.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
climate_station_df.groupby(['region_name'])['station_name'].value_counts().rename(columns={'station_name':'old_station_name'}, inplace=True).reset_index().rename(columns={0: 'Num of Records'}).sort_values(by='Num of Records', ascending=False)
# Out:
#                  region_name  \
# 90   Kab. Padang Lawas Utara
# 118  Kota Adm. Jakarta Pusat
# 167           Kota Tangerang
# 7                Kab. Badung
# 104               Kab. Sikka
# 165            Kota Surabaya
# 132            Kota Bengkulu
# 70            Kab. Manggarai
# 124          Kota Balikpapan
# 83           Kab. Nagan Raya
# 55   Kab. Kotawaringin Timur
# 4            Kab. Aceh Utara
# 138               Kota Jambi
# 139            Kota Jayapura
# 65               Kab. Malang
# 45    Kab. Kepulauan Anambas
# 61         Kab. Lombok Barat
# 88              Kab. Nunukan
# 110             Kab. Sumenep
# 81          Kab. Muaro Jambi
# 58      Kab. Lampung Selatan
# 1            Kab. Aceh Besar
# 134                Kota Bima
# 113     Kab. Tapanuli Tengah
# 12       Kab. Barito Selatan
# 156           Kota Pekanbaru
# 152           Kota Palembang
# 59        Kab. Lampung Utara
# 25         Kab. Deli Serdang
# 105             Kab. Sintang
# ..                       ...
# ...
